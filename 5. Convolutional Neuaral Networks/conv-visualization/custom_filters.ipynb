# %% [markdown]
# # Creating a Filter, Edge Detection

# %% [markdown]
# ### Import resources and display image

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

import cv2
import numpy as np

# %matplotlib inline

# Read in the image
image = mpimg.imread('data/curved_lane.jpg')

plt.imshow(image)

# %%
for i in range(3):
    f, axarr = plt.subplots(1,2,figsize=(12,16))
    axarr[0].imshow(image[:,:,i])
    axarr[1].imshow(image[:,:,i],cmap='gray')
    
    plt.show()

# %% [markdown]
# ### Convert the image to grayscale

# %%
# Convert to grayscale for filtering
gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)

plt.imshow(gray, cmap='gray')

# %% [markdown]
# ### Create a custom kernel
#
# Below, given one common type of edge detection filter: a Sobel operator.
#
# The Sobel filter is very commonly used in edge detection and in finding patterns in intensity in an image. Applying a Sobel filter to an image is a way of **taking (an approximation) of the derivative of the image** in the x or y direction, separately. The operators look as follows.
#
# <img src="data/sobel_ops.png" width=200 height=200>
#
#
# Puting the image through a series of filters: first one that blurs the image (takes an average of pixels), and then one that detects the edges.

# %%
# Line Detection
# 3x3 array for edge detection
sobel_y = np.array([[ -1, -2, -1], 
                   [ 0, 0, 0], 
                   [ 1, 2, 1]])

## TODO: Create and apply a Sobel x operator
sobel_x= np.array([[-1,0,1],
                 [-2,0,2],
                 [-1,0,1]])

# Filter the image using filter2D, which has inputs: (grayscale image, bit-depth, kernel)
filtered_image = cv2.filter2D(gray, -1, sobel_y)
# Depth is the data type of the image which you are handling inside OpenCV.
# e.g. CV_8U, means the data is of 8 bit Unsigned char type.

## Plotting horizontal lines
f, axarr = plt.subplots(1,2,figsize=(15,19))
axarr[0].imshow(gray,cmap='gray')
axarr[1].imshow(filtered_image, cmap='gray')
plt.show()

# %%
## Plotting vertical lines
filtered_x = cv2.filter2D(gray, -1, sobel_x)
f, axarr = plt.subplots(1,2,figsize=(15,19))
axarr[0].imshow(gray,cmap='gray')
axarr[1].imshow(filtered_x, cmap='gray')
plt.show()

# %%
# just a little dark
filter1 = np.array([[.1,.1,.1],
           [.1,.1,.1],
          [.1,.1,.1]])
filtered_x = cv2.filter2D(gray, -1, filter1)
f, axarr = plt.subplots(1,2,figsize=(15,19))
axarr[0].imshow(gray,cmap='gray')
axarr[1].imshow(filtered_x, cmap='gray')
plt.show()

# %%
filter1 = np.array([[1,1,1],
           [1,-7,1],
          [1,1,1]])
filtered_x = cv2.filter2D(gray, -1, filter1)
f, axarr = plt.subplots(1,2,figsize=(15,19))
axarr[0].imshow(gray,cmap='gray')
axarr[1].imshow(filtered_x, cmap='gray')
plt.show()

# %%
# using a 5 x 5 filter
filter1 = np.array([[0.1,.2,.3,.2,.1],
                    [0.1,.2,.3,.2,.1],
                    [0.1,.2,.3,.2,.1],
                    [-0.1,-.2,-.3,-.2,-.1],
                    [-0.1,-.2,-.3,-.2,-.1]])
filtered_x = cv2.filter2D(gray, -1, filter1)
f, axarr = plt.subplots(1,2,figsize=(15,19))
axarr[0].imshow(gray,cmap='gray')
axarr[1].imshow(filtered_x, cmap='gray')
plt.show()

# %% [markdown]
# # Further study
#
# [Convolutional Kernals - Setosa](http://setosa.io/ev/image-kernels/)
#
# Another good way to learn more.
